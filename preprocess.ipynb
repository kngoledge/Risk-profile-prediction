# %%
import pandas as pd

df = pd.read_csv('complaints.csv')


# he input is a two variable tuple of string for sector and string for region; this input expresses investment interest for a specific sector in a specific region. The output is a dictionary of strings mapped onto floats with the key as the name of an issue that could arise from the investment of such a project, and the associated value as the probability of that issue’s occurrence. 

# what do we use pytorch for, for simple feedback neural network 
# what is the difference between this and Multi-Label Classification With Neural Networks In Python since we are getting a PDF of this

# %%
df[sector
# Out:
#     IAM Acronym Bank Acronym  IAM id  Year Filed  \
# 0       SPF CRP          ADB      25        2004
# 1       SPF CRP          ADB      25        2004
# 2       SPF CRP          ADB      25        2004
# 3       SPF CRP          ADB      25        2005
# 4       SPF CRP          ADB      25        2005
# 5       SPF CRP          ADB      25        2006
# 6       SPF CRP          ADB      25        2006
# 7       SPF CRP          ADB      25        2006
# 8       SPF CRP          ADB      25        2006
# 9       SPF CRP          ADB      25        2006
# 10      SPF CRP          ADB      25        2007
# 11      SPF CRP          ADB      25        2007
# 12      SPF CRP          ADB      25        2009
# 13      SPF CRP          ADB      25        2009
# 14      SPF CRP          ADB      25        2009
# 15      SPF CRP          ADB      25        2009
# 16      SPF CRP          ADB      25        2009
# 17      SPF CRP          ADB      25        2009
# ...
